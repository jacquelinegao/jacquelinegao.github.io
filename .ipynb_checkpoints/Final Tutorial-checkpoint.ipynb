# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn import linear_model
from sklearn import preprocessing

#feel free to add whatever else we need

# %%
#Anna's cell!

games = pd.read_csv("appstore_games.csv")
games.drop(['URL','ID','Subtitle','Original Release Date','Current Version Release Date'], axis=1, inplace=True)
games.head()
games.columns.values
# Out:
# array(['Name', 'Icon URL', 'Average User Rating', 'User Rating Count',
#        'Price', 'In-app Purchases', 'Description', 'Developer',
#        'Age Rating', 'Languages', 'Size', 'Primary Genre', 'Genres'],
#       dtype=object)

# %%
games=games[['Name','Primary Genre','Genres','Age Rating','Price','In-app Purchases','Average User Rating', 'User Rating Count','Languages','Size','Description','Developer','Icon URL']]

# %%
games
# Out:
#                             Name Primary Genre  \
# 0                         Sudoku         Games
# 1                        Reversi         Games
# 2                        Morocco         Games
# 3                  Sudoku (Free)         Games
# 4                   Senet Deluxe         Games
# ...                          ...           ...
# 17002  Stack Puzzle : Rise Tower         Games
# 17003                  EachOther         Games
# 17004         Rabbit Vs Tortoise         Games
# 17005                     FaTaLL         Games
# 17006   The Three Kingdoms :Bomb         Games
#
#                                        Genres Age Rating  Price  \
# 0                     Games, Strategy, Puzzle         4+   2.99
# 1                      Games, Strategy, Board         4+   1.99
# 2                      Games, Board, Strategy         4+   0.00
# 3                     Games, Strategy, Puzzle         4+   0.00
# 4           Games, Strategy, Board, Education         4+   2.99
# ...                                       ...        ...    ...
# 17002  Games, Entertainment, Casual, Strategy         4+   0.00
# 17003                 Games, Family, Strategy         4+   0.00
# 17004                         Games, Strategy         4+   0.00
# 17005                 Games, Strategy, Action         4+   0.00
# 17006                 Games, Strategy, Puzzle         4+   0.00
#
#         In-app Purchases  Average User Rating  User Rating Count  \
# 0                    NaN                  4.0             3553.0
# 1                    NaN                  3.5              284.0
# 2                    NaN                  3.0             8376.0
# 3                    NaN                  3.5           190394.0
# 4                    NaN                  3.5               28.0
# ...                  ...                  ...                ...
# 17002                NaN                  NaN                NaN
# 17003                NaN                  NaN                NaN
# 17004                NaN                  NaN                NaN
# 17005  9.99, 49.99, 3.99                  NaN                NaN
# 17006                NaN                  NaN                NaN
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 17002                                                 EN   64795648.0
# 17003                                                 EN  110341120.0
# 17004                                                 EN   23207936.0
# 17005                                                 EN  196750336.0
# 17006                                             EN, ZH   22952960.0
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 3      Top 100 free app for over a year.\nRated "Best...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# ...                                                  ...
# 17002  The goal is very simple, move the square horiz...
# 17003  Collect a score while you play!!\n\nBy linking...
# 17004  "Rabbit Vs Tortoise is chess type cool simple ...
# 17005  Upgrade your character and use your skills to ...
# 17006  The protagonist uses the method of placing a b...
#
#                       Developer  \
# 0      Mighty Mighty Good Games
# 1              Kiss The Machine
# 2                   Bayou Games
# 3      Mighty Mighty Good Games
# 4               RoGame Software
# ...                         ...
# 17002               Zhigang Pei
# 17003             Sultan Shindi
# 17004             Vishal Baldha
# 17005              Tayrem Games
# 17006              ming bo tang
#
#                                                 Icon URL
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3      https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# ...                                                  ...
# 17002  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 17003  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 17004  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 17005  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 17006  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
# [17007 rows x 13 columns]

# %%
games['Languages'].unique
# Out:
# <bound method Series.unique of 0        DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# 1                                                       EN
# 2                                                       EN
# 3        DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# 4        DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...
#                                ...
# 17002                                                   EN
# 17003                                                   EN
# 17004                                                   EN
# 17005                                                   EN
# 17006                                               EN, ZH
# Name: Languages, Length: 17007, dtype: object>
